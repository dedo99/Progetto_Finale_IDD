# %% [markdown]
# # CONTROLLO MATCHING

# %%
import os
import pandas as pd
from valentine import valentine_match, valentine_metrics
from valentine.algorithms import Coma, DistributionBased, Cupid
import pprint
import numpy as np

def list2string(x):
    result = ''
    if(isinstance(x, list)):
        for element in x:
            result = result + ', ' + str(element)
        return result[1:]
    else:
        return x

# Load data using pandas
df1 = pd.read_json("schema_mediato_confronto.json")
# df2 = pd.read_json("datasets/output_globaldata.json")
df2 = pd.read_json("datasets/valueToday_dataset.jsonl", lines=True)
# df2 = df2.apply(np.vectorize(list2string))
df2 = df2.applymap(list2string)
display(df2)
# Instantiate matcher and run
# Coma requires java to be installed on your machine
# If java is not an option, all the other algorithms are in Python (e.g., Cupid)
# matcher = Coma(strategy="COMA_OPT")
matcher = DistributionBased(0.9, 0.9)
matches = valentine_match(df1, df2, matcher)
# print(type(matches))
# print(matches)
pp = pprint.PrettyPrinter(indent=4)
# Out:
#                                      id  \
# 0      b9a098214d1a4ce1acc834cf17aef660
# 1      42f1b7d5a40343de9837fc75d74767c3
# 2      85fa8c7dfbb447d898002cb3cfb2fffd
# 3      6b52bb9b50924235b1003c74bb8db227
# 4      d10c3bd4fe924f138454b6f0583de7a1
# ...                                 ...
# 10677  b08a3d47642d44e7a10f8582a14cf9f9
# 10678  6622d097ddd74d8c8c1be4cec195dfb6
# 10679  42e3f369762b44d7977fda3584145175
# 10680  dda34d322ea9415aa399a26e207e6a64
# 10681  3b5fbfbbdad84d3eb761851048e20223
#
#                                                     name world_rank  \
# 0                                                  Apple          1
# 1      Taiwan Semiconductor Manufacturing Company (tsmc)         10
# 2                                     Nvidia Corporation          9
# 3                                     Berkshire Hathaway          8
# 4                                         Meta Platforms          7
# ...                                                  ...        ...
# 10677                                Nilfisk Holding A/s      9,992
# 10678                                           Taikisha      9,991
# 10679                                      Parque Arauco      9,990
# 10680                                       Talos Energy      9,999
# 10681           Ck Life Sciences Int'l., (holdings) Inc.     10,000
#
#       annual_revenue_in_usd annual_net_income_in_usd  \
# 0       394,330 Million USD       99,803 Million USD
# 1        55,306 Million USD       20,783 Million USD
# 2        26,914 Million USD        9,752 Million USD
# 3       354,640 Million USD       89,795 Million USD
# 4       117,930 Million USD       39,370 Million USD
# ...                     ...                      ...
# 10677       994 Million USD           51 Million USD
# 10678     1,527 Million USD           53 Million USD
# 10679       189 Million USD           26 Million USD
# 10680     1,244 Million USD         -182 Million USD
# 10681                   NaN                      NaN
#
#       annual_results_for_year_ending  total_assets_in_usd  \
# 0                           Sep-2022  352,760 Million USD
# 1                           Dec-2021  129,800 Million USD
# 2          For Year Ending  JAN-2022   44,187 Million USD
# 3           For Year ending Dec-2021  956,780 Million USD
# 4                           Dec-2021  165,990 Million USD
# ...                              ...                  ...
# 10677       For Year Ending Dec-2021      841 Million USD
# 10678       For Year Ending Mar-2022    1,665 Million USD
# 10679       For Year Ending Dec-2021    3,084 Million USD
# 10680           Year ending Dec-2021    2,766 Million USD
# 10681                            NaN                  NaN
#
#       total_liabilities_in_usd  total_equity_in_usd headquarters_region_city  \
# 0          302,080 Million USD   50,672 Million USD               California
# 1           54,253 Million USD   75,543 Million USD                  Hsinchu
# 2           17,575 Million USD   26,612 Million USD               California
# 3          443,850 Million USD  514,930 Million USD                 Nebraska
# 4           41,108 Million USD  124,880 Million USD               California
# ...                        ...                  ...                      ...
# 10677          633 Million USD      207 Million USD                      NaN
# 10678          711 Million USD      954 Million USD                      NaN
# 10679        1,651 Million USD    1,433 Million USD                      NaN
# 10680        2,006 Million USD      760 Million USD                    Texas
# 10681                      NaN                  NaN                      NaN
#
#       headquarters_country headquarters_sub_region headquarters_continent  \
# 0                      USA        Northern America               Americas
# 1                   Taiwan         South East Asia                   Asia
# 2                      USA        Northern America               Americas
# 3                      USA        Northern America               Americas
# 4                      USA        Northern America               Americas
# ...                    ...                     ...                    ...
# 10677              Denmark         Northern Europe                 Europe
# 10678                Japan            Eastern Asia                   Asia
# 10679                Chile           South America               Americas
# 10680                  USA        Northern America               Americas
# 10681            Hong Kong            Eastern Asia                   Asia
#
#                                         company_business number_of_employees  \
# 0       Technology, Mobiles & Accessories, Electronic...             154,000
# 1       Technology, Semiconductors, Electronics, Tech...              65,152
# 2       Technology, Semiconductors, Electronics, Tech...              18,975
# 3             Financial Services, Investments, Insurance             372,000
# 4       Communication Services, Internet or Mobile Ap...              77,805
# ...                                                  ...                 ...
# 10677                     Industries, Industry Machinery                 NaN
# 10678   Industries, Electronics, Paints and Coatings,...               5,042
# 10679                                        Real Estate                 NaN
# 10680                                Energy, Oil and Gas                 443
# 10681                          Healthcare, Biotechnology                 NaN
#
#                    ceo                                           founders  \
# 0             Tim Cook            Steve Jobs, Steve Wozniak, Ronald Wayne
# 1            C. C. Wei                                       Morris Chang
# 2         Jensen Huang      Jensen Huang, Chris Malachowsky, Curtis Priem
# 3       Warren Buffett                                       Oliver Chace
# 4      Mark Zuckerberg   Mark Zuckerberg, Andrew McCollum, Eduardo Sav...
# ...                ...                                                ...
# 10677              NaN                                                NaN
# 10678              NaN                                                NaN
# 10679              NaN                                                NaN
# 10680              NaN                                                NaN
# 10681              NaN                                                NaN
#
#                           company_website
# 0                  https://www.apple.com/
# 1                   https://www.tsmc.com/
# 2                  http://www.nvidia.com/
# 3      https://www.berkshirehathaway.com/
# 4               https://www.facebook.com/
# ...                                   ...
# 10677            https://www.nilfisk.com/
# 10678     https://www.taikisha-group.com/
# 10679            https://www.parauco.com/
# 10680         https://www.talosenergy.com
# 10681    https://www.ck-lifesciences.com/
#
# [10682 rows x 18 columns]

# %%
pp.pprint(matches)
# Out:
# {   (('table_1', 'area_served'), ('table_2', 'headquarters_continent')): 0.8377128325544686,
#     (('table_1', 'country'), ('table_2', 'headquarters_country')): 0.8807710731409065,
#     (('table_1', 'employees'), ('table_2', 'number_of_employees')): 0.7121586240337022,
#     (('table_1', 'employees'), ('table_2', 'world_rank')): 0.9251787351957952,
#     (('table_1', 'headquarters'), ('table_2', 'headquarters_region_city')): 0.9587807736553855,
#     (('table_1', 'name'), ('table_2', 'name')): 0.8885161921180947,
#     (('table_1', 'website'), ('table_2', 'company_website')): 0.9261661952364245}

# %% [markdown]
# # CREAZIONE SCHEMA MEDIATO

# %%
import os
import pandas as pd
from valentine import valentine_match, valentine_metrics
from valentine.algorithms import Coma, DistributionBased
import pprint

# %%
# ---------------------------------------------------------
# CREATA PER INIZIALIZZARE UN DATASET FITTIZIO MA ORA NON
# SI UTILIZZA IL DATASET FITTIZIO DA NOI CREATO MANUALMENTE
# ---------------------------------------------------------
def creation_dataset_confronto(df1):
  # Load data using pandas
  df2 = pd.read_json("datasets/output_disfold.json")

  matcher_coma = Coma(strategy="COMA_OPT")
  matches_coma = valentine_match(df1, df2, matcher_coma)

  attributi_mediato = []
  attributi_dataset = []
  for i in matches_coma:
    if matches_coma[i] > 0.5:
      attributi_mediato.append(i[0][1])
      attributi_dataset.append(i[1][1])

  for i in df2.index:
      data = {}
      # print(i)
      for d,m in zip(attributi_dataset,attributi_mediato):
        # print(df2[d][i])
        data[m] = df2[d][i]
      temp_data=pd.DataFrame([data])
      df1=pd.concat([df1, temp_data], ignore_index=True)

  return df1

# %%
def creation_df_log_matcher(df_logmachers_temp, matches, i, type, name_dataset):
  record = {}
  record['tab1'] = i[0][0]
  record['attr1'] = i[0][1]
  record['tab2'] = name_dataset
  record['attr2'] = i[1][1]
  record['prob'] = matches[i]
  if type == 'coma':
    record['matcher'] = 'Coma'
  else:
    record['matcher'] = 'DistributionBased'
  temp_record=pd.DataFrame([record])
  # df_logmachers=df_logmachers.append(record, ignore_index=True)
  df_logmachers_temp=pd.concat([df_logmachers_temp, temp_record], ignore_index=True)
  return df_logmachers_temp

# %%
def creation_schema_alignment(df1, df2, df_confronto, df_logmachers, name_dataset):

  # Instantiate matcher and run
  # Coma requires java to be installed on your machine
  # If java is not an option, all the other algorithms are in Python (e.g., Cupid)
  matcher_coma = Coma(strategy="COMA_OPT")
  matches_coma = valentine_match(df1, df2, matcher_coma)

  distr_run = False

  df_logmachers_temp = pd.DataFrame(columns = ['tab1' , 'attr1', 'tab2', 'attr2', 'prob', 'matcher'])
 
  attributi_mediato = []
  attributi_dataset = []
  for i in matches_coma:
    df_logmachers_temp = creation_df_log_matcher(df_logmachers_temp, matches_coma, i, 'coma', name_dataset)
    if matches_coma[i] > 0.5:
      attributi_mediato.append(i[0][1])
      attributi_dataset.append(i[1][1])
    else:
      try:
        if not distr_run:
          matcher_distr = DistributionBased()
          matches_distr = valentine_match(df_confronto, df2, matcher_distr)
          distr_run = True
        # distribution based già instanziato
        # log del matcher su Distribution Based
        df_logmachers_temp = creation_df_log_matcher(df_logmachers_temp, matches_distr, i, 'distribution', name_dataset)
        # se nel Distribution Based c'è la stessa coppia di attributi 
        # che fa match con valore superiore a 0.5 allora fa match
        if matches_distr[i] > 0.5:
          attributi_mediato.append(i[0][1])
          attributi_dataset.append(i[1][1])
      except:
        pass
  # print(attributi_dataset)
  # print(attributi_mediato)

  df1_temp = pd.DataFrame(columns = ['name' , 'industry', 'market_cap', 'employees', 'country', 'headquarters', 'address', 'sector', 'ceo', 'founded', 'founders', 'share_price', 'website', 'stock', 'area_served', 'revenue'])

  # inserimento dei dati nel dataframe
  for i in df2.index:
    data = {}
    # print(i)
    for d,m in zip(attributi_dataset,attributi_mediato):
      # print(df2[d][i])
      data[m] = df2[d][i]
    temp_data=pd.DataFrame([data])
    df1_temp=pd.concat([df1_temp, temp_data], ignore_index=True)

  pp = pprint.PrettyPrinter(indent=4)

  # stampa dei matchers
  pp.pprint(matches_coma)
  if distr_run:
    pp.pprint(matches_distr)


  return df1_temp, df_logmachers_temp
  # print(df1)

# %%
#funzione utilizzata per trasformare gli elementi del dataframe che sono una lista in stringa 
def list2string(x):
    result = ''
    if(isinstance(x, list)):
        for element in x:
            result = result + ', ' + str(element)
        return result[1:]
    else:
        return x

# %%
from threading import Thread
import time
class IlMioThread (Thread):

    def __init__(self, df1, df2, df_confronto, df_logmachers, name_dataset):
        Thread.__init__(self)
        self.df1 = df1
        self.df2 = df2
        self.df_confronto = df_confronto
        self.df_logmachers = df_logmachers
        self.name_dataset = name_dataset
   
    def run(self):
        try:
            self.df1, self.df_logmachers = creation_schema_alignment(self.df1, self.df2, self.df_confronto, self.df_logmachers, self.name_dataset)
        except:
            print("ERRORE " + str(self.name_dataset))

# %%
from pathlib import Path
from itertools import zip_longest
import time
#formati json, csv, xls, xlsx, jsonl
df1 = pd.DataFrame(columns = ['name' , 'industry', 'market_cap', 'employees', 'country', 'headquarters', 'address', 'sector', 'ceo', 'founded', 'founders', 'share_price', 'website', 'stock', 'area_served', 'revenue'])
# df_confronto = creation_dataset_confronto(df1)
df_confronto = pd.read_json('output_alignment_multithread/schema_mediato.json')
df_logmachers = pd.DataFrame(columns = ['tab1' , 'attr1', 'tab2', 'attr2', 'prob', 'matcher'])


df1_a = df1
df1_b = df1
df1_c = df1
df1_d = df1
df1_e = df1

df_logmachers_a = df_logmachers
df_logmachers_b = df_logmachers
df_logmachers_c = df_logmachers
df_logmachers_d = df_logmachers
df_logmachers_e = df_logmachers


#numero di errori nell'esecuzione di file
num_error = 0

directory = 'datasets'
dataset_list_json = Path(directory).glob('*.json')
dataset_list_jsonl = Path(directory).glob('*.jsonl')
dataset_list_csv = Path(directory).glob('*.csv')
dataset_list_xls = Path(directory).glob('*.xls')
dataset_list_xlsx = Path(directory).glob('*.xlsx')
i = 0

start_time = time.time()


for a,b,c,d,e in zip_longest(dataset_list_json, dataset_list_jsonl, dataset_list_csv, dataset_list_xls, dataset_list_xlsx, fillvalue='?'):

  df1_a = df1
  df1_b = df1
  df1_c = df1
  df1_d = df1
  df1_e = df1

  df_logmachers_a = df_logmachers
  df_logmachers_b = df_logmachers
  df_logmachers_c = df_logmachers
  df_logmachers_d = df_logmachers
  df_logmachers_e = df_logmachers


  if a != '?':
    print(str(i) + " " + str(a))
    i=i+1
    df2_a = pd.read_json(a)
    # trasforma le celle del dataframe che hanno liste in stringhe
    df2_a = df2_a.applymap(list2string)
    name_dataset_a = str(a).split('\\')[1]
    thread1 = IlMioThread(df1_a, df2_a, df_confronto, df_logmachers_a, name_dataset_a)
    thread1.start()
  else:
    thread1 = None
  
  if b != '?':
    print(str(i) + " " + str(b))
    i=i+1
    df2_b = pd.read_json(b, lines=True)
    # trasforma le celle del dataframe che hanno liste in stringhe
    df2_b = df2_b.applymap(list2string)
    name_dataset_b = str(b).split('\\')[1]
    thread2 = IlMioThread(df1_b, df2_b, df_confronto, df_logmachers_b, name_dataset_b)
    thread2.start()
  else:
    thread2 = None

  
  if c != '?':
    print(str(i) + " " + str(c))
    i=i+1
    df2_c = pd.read_csv(c, encoding='ISO-8859-1')
    # trasforma le celle del dataframe che hanno liste in stringhe
    df2_c = df2_c.applymap(list2string)
    name_dataset_c = str(c).split('\\')[1]
    thread3 = IlMioThread(df1_c, df2_c, df_confronto, df_logmachers_c, name_dataset_c)
    thread3.start()
  else:
    thread3 = None

  if d != '?':
    print(str(i) + " " + str(d))
    i=i+1
    df2_d = pd.read_excel(d)
    # trasforma le celle del dataframe che hanno liste in stringhe
    df2_d = df2_d.applymap(list2string)
    name_dataset_d = str(d).split('\\')[1]
    thread4 = IlMioThread(df1_d, df2_d, df_confronto, df_logmachers_d, name_dataset_d)
    thread4.start()
  else:
    thread4 = None

  if e != '?':
    print(str(i) + " " + str(e))
    i=i+1
    df2_e = pd.read_excel(e)
    # trasforma le celle del dataframe che hanno liste in stringhe
    df2_e = df2_e.applymap(list2string)
    name_dataset_e = str(e).split('\\')[1]
    thread5 = IlMioThread(df1_e, df2_e, df_confronto, df_logmachers_e, name_dataset_e)
    thread5.start()
  else:
    thread5 = None


  if thread1 != None:
    thread1.join()
  if thread2 != None:
    thread2.join()
  if thread3 != None:
    thread3.join()
  if thread4 != None:
    thread4.join()
  if thread5 != None:
    thread5.join()

  if thread1 != None:
    df1=pd.concat([df1, thread1.df1], ignore_index=True)
  if thread2 != None:
    df1=pd.concat([df1, thread2.df1], ignore_index=True)
  if thread3 != None:
    df1=pd.concat([df1, thread3.df1], ignore_index=True)
  if thread4 != None:
    df1=pd.concat([df1, thread4.df1], ignore_index=True)
  if thread5 != None:
    df1=pd.concat([df1, thread5.df1], ignore_index=True)
  
  
  if thread1 != None:
    df_logmachers=pd.concat([df_logmachers, thread1.df_logmachers], ignore_index=True)
  if thread2 != None:
    df_logmachers=pd.concat([df_logmachers, thread2.df_logmachers], ignore_index=True)
  if thread3 != None:
    df_logmachers=pd.concat([df_logmachers, thread3.df_logmachers], ignore_index=True)
  if thread4 != None:
    df_logmachers=pd.concat([df_logmachers, thread4.df_logmachers], ignore_index=True)
  if thread5 != None:
    df_logmachers=pd.concat([df_logmachers, thread5.df_logmachers], ignore_index=True)
  

  
end_time = time.time()
total_time = end_time - start_time

display(df1)
display(df_confronto)
display(df_logmachers)
print("Tempo Esecuzione: " + str(total_time))
# Out:
# 0 datasets\cbinsights.json
# 1 datasets\companiesMarketCap_dataset.jsonl
# 2 datasets\campaignindia.csv
# 3 datasets\MalPatSaj-companiesmarketcap.com.xls
# 4 datasets\MalPatSaj-disfold.com.xlsx
# {   (('table_1', 'country'), ('table_2', 'CATEGORY')): 0.31707317,
#     (('table_1', 'market_cap'), ('table_2', 'MAIN MARKET')): 0.42591837,
#     (('table_1', 'name'), ('table_2', 'BRAND NAME')): 0.42887965,
#     (('table_1', 'stock'), ('table_2', 'RANK')): 0.24250546}
# {   (('table_1', 'country'), ('table_2', 'MAIN MARKET')): 0.9293330321647632,
#     (('table_1', 'headquarters'), ('table_2', 'MAIN MARKET')): 0.9449324384689473,
#     (('table_1', 'name'), ('table_2', 'BRAND NAME')): 0.9747644844671638}
# {   (('table_1', 'country'), ('table_2', 'country')): 0.7812582,
#     (('table_1', 'founded'), ('table_2', 'datejoined')): 0.28348395,
#     (('table_1', 'industry'), ('table_2', 'industry')): 0.78370917,
#     (('table_1', 'name'), ('table_2', 'valuation')): 0.22510847,
#     (('table_1', 'sector'), ('table_2', 'selectinvestors')): 0.35179862}
# {   (('table_1', 'country'), ('table_2', 'country')): 0.9570572901040193,
#     (('table_1', 'headquarters'), ('table_2', 'country')): 0.8915379535894119,
#     (('table_1', 'stock'), ('table_2', 'selectinvestors')): 0.8972717065084623}
# c:\Users\andre\AppData\Local\Programs\Python\Python39\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# c:\Users\andre\AppData\Local\Programs\Python\Python39\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# {   (('table_1', 'country'), ('table_2', 'Country')): 0.8457614,
#     (('table_1', 'industry'), ('table_2', 'Industry')): 0.84821236,
#     (('table_1', 'market_cap'), ('table_2', 'MarketCap')): 0.7106706,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.8363075,
#     (('table_1', 'sector'), ('table_2', 'Sector')): 0.843004,
#     (('table_1', 'stock'), ('table_2', 'Stock')): 0.83987904}
# {   (('table_1', 'country'), ('table_2', 'country')): 0.811216,
#     (('table_1', 'employees'), ('table_2', 'categories')): 0.29485422,
#     (('table_1', 'founded'), ('table_2', 'id')): 0.30935657,
#     (('table_1', 'market_cap'), ('table_2', 'market_cap')): 0.81783354,
#     (('table_1', 'name'), ('table_2', 'name')): 0.8017621,
#     (('table_1', 'share_price'), ('table_2', 'share_price')): 0.8196193,
#     (('table_1', 'stock'), ('table_2', 'rank')): 0.30294633}
# {   (('table_1', 'country'), ('table_2', 'country')): 0.9684471300891391,
#     (('table_1', 'headquarters'), ('table_2', 'country')): 0.9489760535838979,
#     (('table_1', 'name'), ('table_2', 'name')): 0.9936697435029268}
# {   (('table_1', 'country'), ('table_2', 'Country')): 0.802208,
#     (('table_1', 'market_cap'), ('table_2', 'MarketCap')): 0.6671172,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.7927542,
#     (('table_1', 'share_price'), ('table_2', 'Price')): 0.49910343,
#     (('table_1', 'stock'), ('table_2', 'Symbol')): 0.2597665}
# {   (('table_1', 'country'), ('table_2', 'Country')): 0.9845074793988434,
#     (('table_1', 'headquarters'), ('table_2', 'Country')): 0.9579490376297161,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.9934091861187785,
#     (('table_1', 'name'), ('table_2', 'Symbol')): 0.9549821180769378,
#     (('table_1', 'stock'), ('table_2', 'Name')): 0.89155040163027,
#     (('table_1', 'stock'), ('table_2', 'Symbol')): 0.9386777136920147}
# 5 datasets\companiesmarketcap.json
# 6 datasets\disfold_dataset.jsonl
# 7 datasets\company_social_urls.csv
# 8 datasets\MalPatSaj-forbes.com.xls
# {   (('table_1', 'ceo'), ('table_2', 'ceo')): 0.831255,
#     (('table_1', 'employees'), ('table_2', 'employees')): 0.84947366,
#     (('table_1', 'founded'), ('table_2', 'founded')): 0.8448297,
#     (('table_1', 'headquarters'), ('table_2', 'headquarters_country')): 0.6357422,
#     (('table_1', 'market_cap'), ('table_2', 'market_cap')): 0.8514473,
#     (('table_1', 'name'), ('table_2', 'name')): 0.83537585}
# {   (('table_1', 'address'), ('table_2', 'Pinterest')): 0.17812456,
#     (('table_1', 'country'), ('table_2', 'Company')): 0.3124383,
#     (('table_1', 'industry'), ('table_2', 'Instagram')): 0.21795724,
#     (('table_1', 'sector'), ('table_2', 'Twitter')): 0.19300869,
#     (('table_1', 'stock'), ('table_2', 'Facebook')): 0.19300869}
# {   (('table_1', 'name'), ('table_2', 'Company')): 0.9838173350639218,
#     (('table_1', 'stock'), ('table_2', 'Company')): 0.9291092056273674}
# {   (('table_1', 'address'), ('table_2', 'Assets')): 0.30833468,
#     (('table_1', 'country'), ('table_2', 'Country')): 0.7905094,
#     (('table_1', 'employees'), ('table_2', 'Sales')): 0.31992114,
#     (('table_1', 'market_cap'), ('table_2', 'Market Value')): 0.4463486,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.78105557}
# {   (('table_1', 'country'), ('table_2', 'Country')): 0.9371018189403324,
#     (('table_1', 'headquarters'), ('table_2', 'Country')): 0.9207521692081404,
#     (('table_1', 'market_cap'), ('table_2', 'Assets')): 0.9067759892698579,
#     (('table_1', 'market_cap'), ('table_2', 'Market Value')): 0.9602484346767031,
#     (('table_1', 'market_cap'), ('table_2', 'Profit')): 0.9116678620384755,
#     (('table_1', 'market_cap'), ('table_2', 'Sales')): 0.922581990734386,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.9904172217786757,
#     (('table_1', 'stock'), ('table_2', 'Name')): 0.9567126769095068}
# {   (('table_1', 'country'), ('table_2', 'country')): 0.8025657,
#     (('table_1', 'employees'), ('table_2', 'categories')): 0.28620395,
#     (('table_1', 'market_cap'), ('table_2', 'marketcap')): 0.66747487,
#     (('table_1', 'name'), ('table_2', 'name')): 0.79311186,
#     (('table_1', 'share_price'), ('table_2', 'sharePrice')): 0.67961013,
#     (('table_1', 'stock'), ('table_2', 'rank')): 0.29429606}
# {   (('table_1', 'country'), ('table_2', 'country')): 0.9796130374804906,
#     (('table_1', 'headquarters'), ('table_2', 'country')): 0.9367460441350831,
#     (('table_1', 'market_cap'), ('table_2', 'marketcap')): 0.9745431183627457,
#     (('table_1', 'name'), ('table_2', 'code')): 0.9400085421484569,
#     (('table_1', 'name'), ('table_2', 'name')): 0.9979929318495914,
#     (('table_1', 'share_price'), ('table_2', 'sharePrice')): 0.9966651060537719,
#     (('table_1', 'stock'), ('table_2', 'code')): 0.9879947901053401,
#     (('table_1', 'stock'), ('table_2', 'name')): 0.9381384266618344}
# 9 datasets\disfold.com.json
# 10 datasets\hitHorizons_dataset.jsonl
# 11 datasets\DDD-cbinsight.com.csv
# 12 datasets\MalPatSaj-wikipedia.org.xls
# {   (('table_1', 'address'), ('table_2', 'address')): 0.7944409,
#     (('table_1', 'employees'), ('table_2', 'sic_code')): 0.2648777,
#     (('table_1', 'founded'), ('table_2', 'id')): 0.29258153,
#     (('table_1', 'industry'), ('table_2', 'industry')): 0.79689187,
#     (('table_1', 'name'), ('table_2', 'name')): 0.7849871,
#     (('table_1', 'share_price'), ('table_2', 'sic_code')): 0.26525867}
# {(('table_1', 'industry'), ('table_2', 'industry')): 0.9156369288090114}
# {   (('table_1', 'country'), ('table_2', 'country')): 0.81663823,
#     (('table_1', 'founded'), ('table_2', 'founded')): 0.81663823,
#     (('table_1', 'industry'), ('table_2', 'industry')): 0.8190892,
#     (('table_1', 'name'), ('table_2', 'name')): 0.8071844,
#     (('table_1', 'stock'), ('table_2', 'stage')): 0.37027967}
# {   (('table_1', 'country'), ('table_2', 'city')): 0.9646821682887549,
#     (('table_1', 'country'), ('table_2', 'country')): 0.9119443682635514,
#     (('table_1', 'country'), ('table_2', 'investors')): 0.8985187566272252,
#     (('table_1', 'country'), ('table_2', 'name')): 0.8936544557036346,
#     (('table_1', 'founded'), ('table_2', 'founded')): 0.6923463818427691,
#     (('table_1', 'headquarters'), ('table_2', 'city')): 0.9810183940727103,
#     (('table_1', 'headquarters'), ('table_2', 'country')): 0.8476303613589504,
#     (('table_1', 'headquarters'), ('table_2', 'investors')): 0.946213200893697,
#     (('table_1', 'headquarters'), ('table_2', 'name')): 0.93594599189282,
#     (('table_1', 'industry'), ('table_2', 'industry')): 0.9700830256045041,
#     (('table_1', 'market_cap'), ('table_2', 'valuation')): 0.9562337651313221,
#     (('table_1', 'name'), ('table_2', 'city')): 0.9763322900879122,
#     (('table_1', 'name'), ('table_2', 'country')): 0.8671716215618845,
#     (('table_1', 'name'), ('table_2', 'investors')): 0.9915601004704963,
#     (('table_1', 'name'), ('table_2', 'name')): 0.9736963483361868,
#     (('table_1', 'revenue'), ('table_2', 'valuation')): 0.8478201029072353}
# {   (('table_1', 'employees'), ('table_2', 'Notes')): 0.36392817,
#     (('table_1', 'founded'), ('table_2', 'Founded')): 0.84105235,
#     (('table_1', 'headquarters'), ('table_2', 'Headquarters')): 0.8510791,
#     (('table_1', 'industry'), ('table_2', 'Industry')): 0.8435033,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.8315985,
#     (('table_1', 'sector'), ('table_2', 'Sector')): 0.838295}
# {   (('table_1', 'founded'), ('table_2', 'Founded')): 0.8842149769344929,
#     (('table_1', 'headquarters'), ('table_2', 'Headquarters')): 0.9673461775235294,
#     (('table_1', 'industry'), ('table_2', 'Sector')): 0.9387382079780737,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.992902406071746,
#     (('table_1', 'name'), ('table_2', 'Notes')): 0.9651959950830127,
#     (('table_1', 'sector'), ('table_2', 'Name')): 0.9084226655442557,
#     (('table_1', 'sector'), ('table_2', 'Notes')): 0.9634825366665823,
#     (('table_1', 'stock'), ('table_2', 'Name')): 0.926171514306728,
#     (('table_1', 'stock'), ('table_2', 'Notes')): 0.8950932163784646}
# {   (('table_1', 'ceo'), ('table_2', 'ceo')): 0.8211616,
#     (('table_1', 'employees'), ('table_2', 'employees')): 0.83938026,
#     (('table_1', 'headquarters'), ('table_2', 'headquarters')): 0.84476304,
#     (('table_1', 'market_cap'), ('table_2', 'market_cap')): 0.8413539,
#     (('table_1', 'name'), ('table_2', 'name')): 0.82528245,
#     (('table_1', 'stock'), ('table_2', 'link')): 0.32646668}
# {   (('table_1', 'employees'), ('table_2', 'employees')): 0.9364956723288971,
#     (('table_1', 'market_cap'), ('table_2', 'market_cap')): 0.9262370520733082,
#     (('table_1', 'name'), ('table_2', 'name')): 0.9722453883759421,
#     (('table_1', 'stock'), ('table_2', 'name')): 0.9115680356410697}
# 13 datasets\disfold.json
# 14 datasets\valueToday_dataset.jsonl
# 15 datasets\DDD-companiesmarketcap.com.csv
# {   (('table_1', 'country'), ('table_2', 'country')): 0.8495943,
#     (('table_1', 'industry'), ('table_2', 'industry')): 0.85204524,
#     (('table_1', 'market_cap'), ('table_2', 'marketCap')): 0.71450347,
#     (('table_1', 'name'), ('table_2', 'name')): 0.84014046,
#     (('table_1', 'sector'), ('table_2', 'sector')): 0.8468369,
#     (('table_1', 'stock'), ('table_2', 'stock')): 0.8437119}
# {   (('table_1', 'country'), ('table_2', 'country')): 0.8071872,
#     (('table_1', 'employees'), ('table_2', 'categories')): 0.29082543,
#     (('table_1', 'market_cap'), ('table_2', 'marketcap')): 0.6720964,
#     (('table_1', 'name'), ('table_2', 'name')): 0.7977333,
#     (('table_1', 'share_price'), ('table_2', 'share_price')): 0.8155905,
#     (('table_1', 'stock'), ('table_2', 'rank')): 0.29891753}
# {   (('table_1', 'headquarters'), ('table_2', 'name')): 0.957539310644243,
#     (('table_1', 'name'), ('table_2', 'name')): 0.9962149508223769,
#     (('table_1', 'share_price'), ('table_2', 'share_price')): 0.996118569951893,
#     (('table_1', 'stock'), ('table_2', 'name')): 0.9374494105915196}
# {   (('table_1', 'address'), ('table_2', 'company_business')): 0.32536897,
#     (('table_1', 'ceo'), ('table_2', 'ceo')): 0.8019144,
#     (('table_1', 'employees'), ('table_2', 'number_of_employees')): 0.5471067,
#     (('table_1', 'founders'), ('table_2', 'founders')): 0.81794,
#     (('table_1', 'headquarters'), ('table_2', 'headquarters_country')): 0.60640156,
#     (('table_1', 'name'), ('table_2', 'name')): 0.8060352,
#     (('table_1', 'revenue'), ('table_2', 'annual_revenue_in_usd')): 0.38044006,
#     (('table_1', 'stock'), ('table_2', 'world_rank')): 0.26223826,
#     (('table_1', 'website'), ('table_2', 'company_website')): 0.5335994}
# {   (('table_1', 'country'), ('table_2', 'headquarters_country')): 0.9974683555773997,
#     (('table_1', 'country'), ('table_2', 'headquarters_region_city')): 0.9289920995284991,
#     (('table_1', 'employees'), ('table_2', 'number_of_employees')): 0.994295315110331,
#     (('table_1', 'employees'), ('table_2', 'world_rank')): 0.9316035002766812,
#     (('table_1', 'headquarters'), ('table_2', 'headquarters_country')): 0.9508015037746931,
#     (('table_1', 'headquarters'), ('table_2', 'headquarters_region_city')): 0.9762397071734846,
#     (('table_1', 'name'), ('table_2', 'founders')): 0.9974623853577637,
#     (('table_1', 'name'), ('table_2', 'name')): 0.9837965957579609}
# 16 datasets\forbes.com.json
# 17 datasets\DDD-ft.com.csv
# {   (('table_1', 'country'), ('table_2', 'country')): 0.81169474,
#     (('table_1', 'employees'), ('table_2', 'number_of_employees_2017')): 0.41764307,
#     (('table_1', 'employees'), ('table_2', 'number_of_employees_2020')): 0.41764307,
#     (('table_1', 'founded'), ('table_2', 'founding_year')): 0.43914568,
#     (('table_1', 'name'), ('table_2', 'name')): 0.8022409,
#     (('table_1', 'revenue'), ('table_2', 'revenue_2017_euro')): 0.49534726,
#     (('table_1', 'revenue'), ('table_2', 'revenue_2020_euro')): 0.49534726,
#     (('table_1', 'sector'), ('table_2', 'sector')): 0.8089374}
# {   (('table_1', 'country'), ('table_2', 'country')): 0.8718060536170189,
#     (('table_1', 'employees'), ('table_2', 'number_of_employees_2017')): 0.9924648803870058,
#     (('table_1', 'employees'), ('table_2', 'number_of_employees_2020')): 0.9751580110945717,
#     (('table_1', 'employees'), ('table_2', 'revenue_2017_euro')): 0.9658873695213854,
#     (('table_1', 'headquarters'), ('table_2', 'country')): 0.9216505788431943,
#     (('table_1', 'industry'), ('table_2', 'sector')): 0.9825710923228528,
#     (('table_1', 'market_cap'), ('table_2', 'number_of_employees_2017')): 0.8848176698177721,
#     (('table_1', 'market_cap'), ('table_2', 'number_of_employees_2020')): 0.8871293779825387,
#     (('table_1', 'market_cap'), ('table_2', 'revenue_2017_euro')): 0.8893124750524893,
#     (('table_1', 'name'), ('table_2', 'name')): 0.9871721829628388,
#     (('table_1', 'sector'), ('table_2', 'sector')): 0.9208156994388526}
# {   (('table_1', 'ceo'), ('table_2', 'ceo')): 0.85604453,
#     (('table_1', 'country'), ('table_2', 'country')): 0.8696192,
#     (('table_1', 'employees'), ('table_2', 'employees')): 0.87426317,
#     (('table_1', 'founded'), ('table_2', 'founded')): 0.8696192,
#     (('table_1', 'industry'), ('table_2', 'industry')): 0.87207013,
#     (('table_1', 'name'), ('table_2', 'name')): 0.86016536,
#     (('table_1', 'revenue'), ('table_2', 'revenue')): 0.8696192,
#     (('table_1', 'stock'), ('table_2', 'link')): 0.36134958}
# {   (('table_1', 'country'), ('table_2', 'country')): 0.962941823985685,
#     (('table_1', 'employees'), ('table_2', 'employees')): 0.9678546296628667,
#     (('table_1', 'founded'), ('table_2', 'founded')): 0.9880924312462782,
#     (('table_1', 'headquarters'), ('table_2', 'country')): 0.9597176617500329,
#     (('table_1', 'industry'), ('table_2', 'industry')): 0.9341763417560283,
#     (('table_1', 'market_cap'), ('table_2', 'revenue')): 0.9741192313909174,
#     (('table_1', 'name'), ('table_2', 'name')): 0.9885132070828989,
#     (('table_1', 'stock'), ('table_2', 'name')): 0.9503291047588509}
# 18 datasets\ft.com.json
# 19 datasets\DDD-teamblind.com.csv
# {   (('table_1', 'employees'), ('table_2', 'size')): 0.32602358,
#     (('table_1', 'founded'), ('table_2', 'founded')): 0.82334983,
#     (('table_1', 'industry'), ('table_2', 'industry')): 0.8258008,
#     (('table_1', 'name'), ('table_2', 'name')): 0.813896,
#     (('table_1', 'website'), ('table_2', 'website')): 0.82334983}
# {   (('table_1', 'country'), ('table_2', 'locations')): 0.9322281728984104,
#     (('table_1', 'headquarters'), ('table_2', 'locations')): 0.9813277516870517,
#     (('table_1', 'sector'), ('table_2', 'industry')): 0.9770339162385051}
# {   (('table_1', 'country'), ('table_2', 'country')): 0.8565519,
#     (('table_1', 'employees'), ('table_2', 'employees')): 0.8611958,
#     (('table_1', 'founded'), ('table_2', 'founded')): 0.8565519,
#     (('table_1', 'industry'), ('table_2', 'industry')): 0.8590028,
#     (('table_1', 'name'), ('table_2', 'name')): 0.847098,
#     (('table_1', 'revenue'), ('table_2', 'revenue')): 0.8565519,
#     (('table_1', 'stock'), ('table_2', 'link')): 0.34828222}
# {   (('table_1', 'country'), ('table_2', 'country')): 0.9944555000369464,
#     (('table_1', 'employees'), ('table_2', 'employees')): 0.9755797228442075,
#     (('table_1', 'headquarters'), ('table_2', 'country')): 0.8917186380120143,
#     (('table_1', 'industry'), ('table_2', 'industry')): 0.9173070145647081,
#     (('table_1', 'name'), ('table_2', 'name')): 0.9853146017833316,
#     (('table_1', 'sector'), ('table_2', 'industry')): 0.9715586265475015,
#     (('table_1', 'stock'), ('table_2', 'name')): 0.9243945563924988,
#     (('table_1', 'website'), ('table_2', 'link')): 0.9304360282779478}
# 20 datasets\gren-companiesmarketcap.com.json
# 21 datasets\disfold.csv
# {   (('table_1', 'ceo'), ('table_2', 'CEO')): 0.8135065,
#     (('table_1', 'employees'), ('table_2', 'Employees')): 0.8317251,
#     (('table_1', 'founded'), ('table_2', 'Founded')): 0.82708114,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.8176273,
#     (('table_1', 'sector'), ('table_2', 'Top Competitor')): 0.3586988}
# {   (('table_1', 'name'), ('table_2', 'Name')): 0.9826491843092322,
#     (('table_1', 'name'), ('table_2', 'Top Competitor')): 0.9843629864616997}
# {   (('table_1', 'country'), ('table_2', 'country')): 0.7953672,
#     (('table_1', 'market_cap'), ('table_2', 'market_capitalization_USD')): 0.48225874,
#     (('table_1', 'name'), ('table_2', 'name')): 0.78591335,
#     (('table_1', 'share_price'), ('table_2', 'price')): 0.4922626}
# {   (('table_1', 'country'), ('table_2', 'country')): 0.9822624943402336,
#     (('table_1', 'employees'), ('table_2', 'price')): 0.9614278938681184,
#     (('table_1', 'founded'), ('table_2', 'price')): 0.8698596059705558,
#     (('table_1', 'founders'), ('table_2', 'name')): 0.853435707720586,
#     (('table_1', 'headquarters'), ('table_2', 'country')): 0.9495062834285268,
#     (('table_1', 'name'), ('table_2', 'name')): 0.9977542489168371,
#     (('table_1', 'stock'), ('table_2', 'name')): 0.9481546624162942}
# 22 datasets\gren-disfold.com.json
# 23 datasets\famcap_germany.csv
# {   (('table_1', 'country'), ('table_2', 'country')): 0.8440309,
#     (('table_1', 'industry'), ('table_2', 'industry')): 0.84648186,
#     (('table_1', 'market_cap'), ('table_2', 'market_capitalization_USD')): 0.5309225,
#     (('table_1', 'name'), ('table_2', 'name')): 0.8345771,
#     (('table_1', 'sector'), ('table_2', 'sector')): 0.84127355,
#     (('table_1', 'stock'), ('table_2', 'stock')): 0.83814853}
# {   (('table_1', 'country'), ('table_2', 'Company')): 0.4036992,
#     (('table_1', 'employees'), ('table_2', 'Employees')): 0.8299118,
#     (('table_1', 'founded'), ('table_2', 'Founded')): 0.8252678,
#     (('table_1', 'headquarters'), ('table_2', 'Headquarters')): 0.8352946,
#     (('table_1', 'revenue'), ('table_2', 'Revenues 2018 $m')): 0.51817954,
#     (('table_1', 'sector'), ('table_2', 'Sector')): 0.8225105,
#     (('table_1', 'stock'), ('table_2', 'Rank')): 0.31699818,
#     (('table_1', 'website'), ('table_2', 'Website')): 0.8252678}
# {   (('table_1', 'employees'), ('table_2', 'Employees')): 0.945108040516674,
#     (('table_1', 'employees'), ('table_2', 'Generation')): 0.9484275887376292,
#     (('table_1', 'headquarters'), ('table_2', 'Headquarters')): 0.9661143223503591,
#     (('table_1', 'name'), ('table_2', 'Company')): 0.953563366353962,
#     (('table_1', 'name'), ('table_2', 'Family ownership')): 0.9502724760125606,
#     (('table_1', 'stock'), ('table_2', 'State (abbreviation)')): 0.9227165282038825}
# 24 datasets\gren-ft.com.json
# 25 datasets\followers.csv
# {   (('table_1', 'country'), ('table_2', 'country')): 0.826169,
#     (('table_1', 'employees'), ('table_2', 'employees_number_2017')): 0.52499247,
#     (('table_1', 'employees'), ('table_2', 'employees_number_2020')): 0.52499247,
#     (('table_1', 'founded'), ('table_2', 'founding_year')): 0.45361993,
#     (('table_1', 'name'), ('table_2', 'name')): 0.8167151,
#     (('table_1', 'revenue'), ('table_2', 'revenue_2017_EU')): 0.53585887,
#     (('table_1', 'revenue'), ('table_2', 'revenue_2020_EU')): 0.53585887,
#     (('table_1', 'sector'), ('table_2', 'sector')): 0.8234116}
# {   (('table_1', 'country'), ('table_2', 'country')): 0.9136909265862376,
#     (('table_1', 'employees'), ('table_2', 'employees_number_2017')): 0.9740844279373513,
#     (('table_1', 'employees'), ('table_2', 'employees_number_2020')): 0.99186830029346,
#     (('table_1', 'founded'), ('table_2', 'founding_year')): 0.7319795368823561,
#     (('table_1', 'headquarters'), ('table_2', 'country')): 0.8833526616102526,
#     (('table_1', 'industry'), ('table_2', 'sector')): 0.9612900844302013,
#     (('table_1', 'name'), ('table_2', 'name')): 0.9873465266427249,
#     (('table_1', 'sector'), ('table_2', 'sector')): 0.972074051224529}
# {   (('table_1', 'address'), ('table_2', 'Pinterest')): 0.17812456,
#     (('table_1', 'country'), ('table_2', 'Company')): 0.3124383,
#     (('table_1', 'industry'), ('table_2', 'Instagram')): 0.21795724,
#     (('table_1', 'sector'), ('table_2', 'Twitter')): 0.19300869,
#     (('table_1', 'stock'), ('table_2', 'Facebook')): 0.19300869}
# {   (('table_1', 'employees'), ('table_2', 'Twitter')): 0.9595777694380444,
#     (('table_1', 'headquarters'), ('table_2', 'Company')): 0.9176918079299636,
#     (('table_1', 'name'), ('table_2', 'Company')): 0.988039876125953,
#     (('table_1', 'stock'), ('table_2', 'Company')): 0.9711672306479642}
# 26 datasets\gren-value.today.json
# 27 datasets\forbes.csv
# {   (('table_1', 'founded'), ('table_2', 'Founded')): 0.8216928,
#     (('table_1', 'industry'), ('table_2', 'Industry')): 0.82414377,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.812239,
#     (('table_1', 'revenue'), ('table_2', 'Revenue')): 0.8216928}
# {   (('table_1', 'ceo'), ('table_2', 'CEO')): 0.7877448,
#     (('table_1', 'employees'), ('table_2', 'employees_number')): 0.5613375,
#     (('table_1', 'headquarters'), ('table_2', 'headquarters_country')): 0.592232,
#     (('table_1', 'market_cap'), ('table_2', 'market_capitalization_2022')): 0.4793657,
#     (('table_1', 'name'), ('table_2', 'name')): 0.79186565,
#     (('table_1', 'revenue'), ('table_2', 'annual_revenue_USD')): 0.39007312}
# {   (('table_1', 'ceo'), ('table_2', 'CEO')): 0.9711998031553741,
#     (('table_1', 'country'), ('table_2', 'headquarters_country')): 0.9413227594982415,
#     (('table_1', 'employees'), ('table_2', 'employees_number')): 0.9802507320789595,
#     (('table_1', 'headquarters'), ('table_2', 'headquarters_country')): 0.9760527395589204,
#     (('table_1', 'name'), ('table_2', 'name')): 0.9950558806100428,
#     (('table_1', 'stock'), ('table_2', 'name')): 0.9437529918261018}
# 28 datasets\igmm-disfold.com.json
# 29 datasets\ft.csv
# {   (('table_1', 'country'), ('table_2', 'Country')): 0.80577993,
#     (('table_1', 'employees'), ('table_2', 'Number of employees 2017')): 0.42116228,
#     (('table_1', 'employees'), ('table_2', 'Number of employees 2020')): 0.42116228,
#     (('table_1', 'founded'), ('table_2', 'Founding Year')): 0.4332309,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.79632616,
#     (('table_1', 'revenue'), ('table_2', 'Revenue 2017 (Ã¢Â‚Â¬)')): 0.47461024,
#     (('table_1', 'revenue'), ('table_2', 'Revenue 2020 (Ã¢Â‚Â¬)')): 0.47461024,
#     (('table_1', 'sector'), ('table_2', 'Sector')): 0.8030226,
#     (('table_1', 'stock'), ('table_2', 'Rank')): 0.29751033}
# {   (('table_1', 'country'), ('table_2', 'Country')): 0.9781231463887804,
#     (('table_1', 'employees'), ('table_2', 'Number of employees 2017')): 0.9861769001616567,
#     (('table_1', 'founded'), ('table_2', 'Founding Year')): 0.8858263678908006,
#     (('table_1', 'headquarters'), ('table_2', 'Country')): 0.952740492222096,
#     (('table_1', 'industry'), ('table_2', 'Sector')): 0.9016953986501738,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.9921187033665805,
#     (('table_1', 'sector'), ('table_2', 'Sector')): 0.989999411088724}
# {   (('table_1', 'ceo'), ('table_2', 'ceo')): 0.87445605,
#     (('table_1', 'country'), ('table_2', 'country')): 0.8880307,
#     (('table_1', 'employees'), ('table_2', 'employees')): 0.8926747,
#     (('table_1', 'founded'), ('table_2', 'founded')): 0.8880307,
#     (('table_1', 'headquarters'), ('table_2', 'headquarters')): 0.89805746,
#     (('table_1', 'industry'), ('table_2', 'industry')): 0.89048165,
#     (('table_1', 'market_cap'), ('table_2', 'marketcap')): 0.7529399,
#     (('table_1', 'name'), ('table_2', 'name')): 0.8785769,
#     (('table_1', 'revenue'), ('table_2', 'revenue')): 0.8880307,
#     (('table_1', 'sector'), ('table_2', 'sector')): 0.88527334,
#     (('table_1', 'stock'), ('table_2', 'link')): 0.37976104,
#     (('table_1', 'stock'), ('table_2', 'rank')): 0.37976104}
# {   (('table_1', 'ceo'), ('table_2', 'ceo')): 0.8749657062404974,
#     (('table_1', 'country'), ('table_2', 'country')): 0.9541887753899607,
#     (('table_1', 'country'), ('table_2', 'headquarters')): 0.9126610288376706,
#     (('table_1', 'employees'), ('table_2', 'employees')): 0.991508807436742,
#     (('table_1', 'employees'), ('table_2', 'rank')): 0.8520362861649462,
#     (('table_1', 'founded'), ('table_2', 'founded')): 0.842501697614769,
#     (('table_1', 'headquarters'), ('table_2', 'country')): 0.949213670083264,
#     (('table_1', 'headquarters'), ('table_2', 'headquarters')): 0.956502690138335,
#     (('table_1', 'industry'), ('table_2', 'industry')): 0.9307058401361634,
#     (('table_1', 'market_cap'), ('table_2', 'marketcap')): 0.9580769567410291,
#     (('table_1', 'name'), ('table_2', 'code')): 0.9016542228876582,
#     (('table_1', 'name'), ('table_2', 'name')): 0.9936085209746558,
#     (('table_1', 'sector'), ('table_2', 'sector')): 0.970733606883941,
#     (('table_1', 'stock'), ('table_2', 'code')): 0.9656802146386337,
#     (('table_1', 'stock'), ('table_2', 'name')): 0.9834484314423022}
# 30 datasets\marketCap2.json
# 31 datasets\MarScoToc-ambitionbox.com.csv
# {   (('table_1', 'country'), ('table_2', 'country')): 0.7904453,
#     (('table_1', 'market_cap'), ('table_2', 'pricecap')): 0.3458412,
#     (('table_1', 'name'), ('table_2', 'name')): 0.78099155,
#     (('table_1', 'share_price'), ('table_2', 'price')): 0.48734078}
# {   (('table_1', 'country'), ('table_2', 'country')): 0.9760026666689231,
#     (('table_1', 'headquarters'), ('table_2', 'country')): 0.9800764811184453,
#     (('table_1', 'market_cap'), ('table_2', 'pricecap')): 0.9321476430069973,
#     (('table_1', 'name'), ('table_2', 'codice')): 0.9308050367942,
#     (('table_1', 'name'), ('table_2', 'name')): 0.9954141903531726,
#     (('table_1', 'share_price'), ('table_2', 'price')): 0.9942974299030386,
#     (('table_1', 'stock'), ('table_2', 'codice')): 0.9717174262831562,
#     (('table_1', 'stock'), ('table_2', 'name')): 0.9480595304727016}
# {   (('table_1', 'ceo'), ('table_2', 'Ownership')): 0.2523626,
#     (('table_1', 'founded'), ('table_2', 'Foundation Year')): 0.40746793,
#     (('table_1', 'headquarters'), ('table_2', 'Headquarter')): 0.6895665,
#     (('table_1', 'industry'), ('table_2', 'Industry')): 0.8044459,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.79254115}
# {   (('table_1', 'headquarters'), ('table_2', 'Headquarter')): 0.8610745850097803,
#     (('table_1', 'industry'), ('table_2', 'Industry')): 0.9685342816929656,
#     (('table_1', 'industry'), ('table_2', 'Ownership')): 0.885240190111648,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.9919395247553482,
#     (('table_1', 'sector'), ('table_2', 'Industry')): 0.9671134998544011,
#     (('table_1', 'sector'), ('table_2', 'Ownership')): 0.6392911472008598,
#     (('table_1', 'stock'), ('table_2', 'Name')): 0.9067362132181651}
# 32 datasets\output_disfold.json
# 33 datasets\MarScoToc-companiesmarketcap.com.csv
# {   (('table_1', 'ceo'), ('table_2', 'ceo')): 0.8978051,
#     (('table_1', 'country'), ('table_2', 'country')): 0.9113798,
#     (('table_1', 'employees'), ('table_2', 'employees')): 0.91602373,
#     (('table_1', 'founded'), ('table_2', 'founded')): 0.9113798,
#     (('table_1', 'headquarters'), ('table_2', 'headquarters')): 0.9214065,
#     (('table_1', 'industry'), ('table_2', 'industry')): 0.91383076,
#     (('table_1', 'market_cap'), ('table_2', 'market_cap')): 0.91799736,
#     (('table_1', 'name'), ('table_2', 'name')): 0.9019259,
#     (('table_1', 'sector'), ('table_2', 'sector')): 0.9086224,
#     (('table_1', 'stock'), ('table_2', 'stock')): 0.90549743}
# {   (('table_1', 'country'), ('table_2', 'Country')): 0.8032092,
#     (('table_1', 'market_cap'), ('table_2', 'Master Cap')): 0.43066013,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.79375535,
#     (('table_1', 'share_price'), ('table_2', 'Share Price')): 0.66051364,
#     (('table_1', 'stock'), ('table_2', 'Rank')): 0.29493955}
# {   (('table_1', 'country'), ('table_2', 'Country')): 0.990897897295135,
#     (('table_1', 'headquarters'), ('table_2', 'Country')): 0.9839576931332239,
#     (('table_1', 'market_cap'), ('table_2', 'Master Cap')): 0.9754616111483526,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.9900852753459896,
#     (('table_1', 'share_price'), ('table_2', 'Share Price')): 0.9664982075280473,
#     (('table_1', 'stock'), ('table_2', 'Name')): 0.9209899485720606}
# 34 datasets\output_globaldata.json
# 35 datasets\MarScoToc-disfold.com.csv
# {   (('table_1', 'country'), ('table_2', 'Country')): 0.82571703,
#     (('table_1', 'industry'), ('table_2', 'Industry')): 0.828168,
#     (('table_1', 'market_cap'), ('table_2', 'MasterCap')): 0.4654311,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.8162632,
#     (('table_1', 'sector'), ('table_2', 'Sector')): 0.82295966}
# {   (('table_1', 'industry'), ('table_2', 'Industry')): 0.9275459048107799,
#     (('table_1', 'industry'), ('table_2', 'Sector')): 0.9518583851462215,
#     (('table_1', 'market_cap'), ('table_2', 'MasterCap')): 0.9838618352111068,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.9905607721417551,
#     (('table_1', 'sector'), ('table_2', 'Industry')): 0.9057566484573895,
#     (('table_1', 'sector'), ('table_2', 'Sector')): 0.9570609608926107}
# {   (('table_1', 'address'), ('table_2', 'address')): 0.8691785,
#     (('table_1', 'employees'), ('table_2', 'number_of_employees')): 0.6007961,
#     (('table_1', 'headquarters'), ('table_2', 'headquarters')): 0.8792052,
#     (('table_1', 'industry'), ('table_2', 'industry')): 0.8716294,
#     (('table_1', 'market_cap'), ('table_2', 'market_cap')): 0.8757961,
#     (('table_1', 'name'), ('table_2', 'name')): 0.85972464,
#     (('table_1', 'revenue'), ('table_2', 'revenue')): 0.8691785,
#     (('table_1', 'website'), ('table_2', 'website')): 0.8691785}
# 36 datasets\output_govuk_bigsize.json
# 37 datasets\MarScoToc-wikipedia.org.csv
# {   (('table_1', 'area_served'), ('table_2', 'Area Served')): 0.69714475,
#     (('table_1', 'founded'), ('table_2', 'Founded')): 0.8398403,
#     (('table_1', 'headquarters'), ('table_2', 'headQuarters')): 0.849867,
#     (('table_1', 'industry'), ('table_2', 'Industry')): 0.84229124,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.8303864}
# {   (('table_1', 'address'), ('table_2', 'registered_office_address')): 0.3718311,
#     (('table_1', 'country'), ('table_2', 'company_type')): 0.22908676,
#     (('table_1', 'name'), ('table_2', 'name')): 0.7488152}
# {}
# 38 datasets\output_wiki.json
# 39 datasets\silvestri-disfold.com.csv
# {   (('table_1', 'country'), ('table_2', 'country')): 0.82727784,
#     (('table_1', 'market_cap'), ('table_2', 'market_value_apr_2022')): 0.43904254,
#     (('table_1', 'name'), ('table_2', 'name')): 0.817824,
#     (('table_1', 'sector'), ('table_2', 'sector')): 0.82452047,
#     (('table_1', 'stock'), ('table_2', 'stock')): 0.82139546}
# {   (('table_1', 'country'), ('table_2', 'country')): 0.961859187460327,
#     (('table_1', 'name'), ('table_2', 'name')): 0.9896698427623974,
#     (('table_1', 'name'), ('table_2', 'stock')): 0.9242700856925736,
#     (('table_1', 'stock'), ('table_2', 'name')): 0.9453735990309378,
#     (('table_1', 'stock'), ('table_2', 'stock')): 0.9709536670228147}
# {   (('table_1', 'employees'), ('table_2', 'number_of_employees')): 0.58523935,
#     (('table_1', 'founded'), ('table_2', 'founded')): 0.8536217,
#     (('table_1', 'founders'), ('table_2', 'founders')): 0.85607266,
#     (('table_1', 'headquarters'), ('table_2', 'headquarters')): 0.8636485,
#     (('table_1', 'industry'), ('table_2', 'industry')): 0.85607266,
#     (('table_1', 'name'), ('table_2', 'name')): 0.8441679,
#     (('table_1', 'revenue'), ('table_2', 'revenue')): 0.8536217,
#     (('table_1', 'sector'), ('table_2', 'services')): 0.3683276,
#     (('table_1', 'website'), ('table_2', 'website')): 0.8536217}
# {   (('table_1', 'country'), ('table_2', 'key_people')): 0.8118228628999724,
#     (('table_1', 'founded'), ('table_2', 'founded')): 0.9186634021570939,
#     (('table_1', 'founders'), ('table_2', 'founders')): 0.9829043229697229,
#     (('table_1', 'industry'), ('table_2', 'key_people')): 0.8291763498519401,
#     (('table_1', 'name'), ('table_2', 'name')): 0.9981312939857866,
#     (('table_1', 'sector'), ('table_2', 'key_people')): 1.0}
# 40 datasets\slytherin-value.today.json
# 41 datasets\silvestri-forbes.com.csv
# {   (('table_1', 'country'), ('table_2', 'country')): 0.7951269,
#     (('table_1', 'market_cap'), ('table_2', 'market_value_apr_2022')): 0.40689164,
#     (('table_1', 'name'), ('table_2', 'name')): 0.7856731,
#     (('table_1', 'revenue'), ('table_2', 'revenue_2022')): 0.5514871}
# {   (('table_1', 'country'), ('table_2', 'country')): 0.9548401790260351,
#     (('table_1', 'market_cap'), ('table_2', 'market_value_apr_2022')): 0.9093163838507622,
#     (('table_1', 'market_cap'), ('table_2', 'revenue_2022')): 0.9106511182229085}
# {   (('table_1', 'ceo'), ('table_2', 'ceo')): 0.83584815,
#     (('table_1', 'country'), ('table_2', 'country')): 0.8494228,
#     (('table_1', 'founded'), ('table_2', 'founded')): 0.8494228,
#     (('table_1', 'industry'), ('table_2', 'industry')): 0.85187376,
#     (('table_1', 'name'), ('table_2', 'name')): 0.839969,
#     (('table_1', 'revenue'), ('table_2', 'revenue')): 0.8494228,
#     (('table_1', 'stock'), ('table_2', 'link')): 0.3411532,
#     (('table_1', 'stock'), ('table_2', 'rank')): 0.3411532}
# {   (('table_1', 'country'), ('table_2', 'ceo')): 0.9313697330416617,
#     (('table_1', 'country'), ('table_2', 'country')): 0.9618644319757166,
#     (('table_1', 'employees'), ('table_2', 'founded')): 0.7485759584285041,
#     (('table_1', 'founded'), ('table_2', 'founded')): 0.9573891804968745,
#     (('table_1', 'headquarters'), ('table_2', 'ceo')): 0.9430838718316756,
#     (('table_1', 'headquarters'), ('table_2', 'country')): 0.9187431017177832,
#     (('table_1', 'name'), ('table_2', 'name')): 0.9906261596788544,
#     (('table_1', 'stock'), ('table_2', 'name')): 0.9049749256622174}
# 42 datasets\value.today.json
# 43 datasets\silvestri-ft.com.csv
# {   (('table_1', 'country'), ('table_2', 'country')): 0.832653,
#     (('table_1', 'employees'), ('table_2', 'employees_2017')): 0.62289464,
#     (('table_1', 'employees'), ('table_2', 'employees_2020')): 0.62289464,
#     (('table_1', 'founded'), ('table_2', 'founding_year')): 0.46010393,
#     (('table_1', 'name'), ('table_2', 'name')): 0.82319915,
#     (('table_1', 'revenue'), ('table_2', 'revenue_2017')): 0.58901316,
#     (('table_1', 'revenue'), ('table_2', 'revenue_2020')): 0.58901316,
#     (('table_1', 'sector'), ('table_2', 'sector')): 0.8298956}
# {   (('table_1', 'country'), ('table_2', 'country')): 0.9255643492697566,
#     (('table_1', 'employees'), ('table_2', 'employees_2017')): 0.9533415046376105,
#     (('table_1', 'name'), ('table_2', 'name')): 0.977356455034713}
# {   (('table_1', 'address'), ('table_2', 'company business')): 0.31335214,
#     (('table_1', 'ceo'), ('table_2', 'ceo')): 0.78989756,
#     (('table_1', 'employees'), ('table_2', 'number of employees')): 0.54550654,
#     (('table_1', 'headquarters'), ('table_2', 'headquarters country')): 0.59438473,
#     (('table_1', 'market_cap'), ('table_2', 'market value (Jan-07-2022)')): 0.34580415,
#     (('table_1', 'name'), ('table_2', 'name')): 0.7940184,
#     (('table_1', 'revenue'), ('table_2', 'annual revenue in USD')): 0.37883985,
#     (('table_1', 'website'), ('table_2', 'company website')): 0.5334873}
# {   (('table_1', 'area_served'), ('table_2', 'headquarters country')): 0.9377583882641015,
#     (('table_1', 'country'), ('table_2', 'headquarters country')): 0.9969833987886678,
#     (('table_1', 'employees'), ('table_2', 'number of employees')): 0.9727032822832755,
#     (('table_1', 'employees'), ('table_2', 'world rank (Jan-07-2022)')): 0.9064381530166287,
#     (('table_1', 'founders'), ('table_2', 'ceo')): 0.8163111350614842,
#     (('table_1', 'headquarters'), ('table_2', 'headquarters country')): 0.9933991577457917,
#     (('table_1', 'name'), ('table_2', 'name')): 0.997639543896697,
#     (('table_1', 'revenue'), ('table_2', 'annual net income in USD')): 0.9427178745542857,
#     (('table_1', 'revenue'), ('table_2', 'annual revenue in USD')): 0.7863628730124839,
#     (('table_1', 'stock'), ('table_2', 'name')): 0.9465826952986972,
#     (('table_1', 'website'), ('table_2', 'company website')): 0.9446059815884733}
# 44 datasets\valueToday2.json
# 45 datasets\silvestri-value.today.csv
# {   (('table_1', 'ceo'), ('table_2', 'ceo')): 0.8250584,
#     (('table_1', 'country'), ('table_2', 'country')): 0.83863306,
#     (('table_1', 'employees'), ('table_2', 'employees_2022')): 0.6288747,
#     (('table_1', 'market_cap'), ('table_2', 'market_value_jan_2020')): 0.4503978,
#     (('table_1', 'market_cap'), ('table_2', 'market_value_jan_2021')): 0.4503978,
#     (('table_1', 'market_cap'), ('table_2', 'market_value_jan_2022')): 0.4503978,
#     (('table_1', 'name'), ('table_2', 'name')): 0.8291792,
#     (('table_1', 'revenue'), ('table_2', 'revenue_2022')): 0.59499323,
#     (('table_1', 'sector'), ('table_2', 'sector')): 0.8358757}
# {   (('table_1', 'country'), ('table_2', 'country')): 0.8625448995180992,
#     (('table_1', 'employees'), ('table_2', 'employees_2022')): 0.9861880978427779,
#     (('table_1', 'name'), ('table_2', 'name')): 0.984481223962393,
#     (('table_1', 'revenue'), ('table_2', 'revenue_2022')): 0.9166200670396153,
#     (('table_1', 'sector'), ('table_2', 'sector')): 0.9738273240142726}
# {   (('table_1', 'ceo'), ('table_2', 'CEO')): 0.7983511,
#     (('table_1', 'country'), ('table_2', 'country')): 0.81192577,
#     (('table_1', 'market_cap'), ('table_2', 'marketCap')): 0.67683494,
#     (('table_1', 'name'), ('table_2', 'name')): 0.80247194,
#     (('table_1', 'stock'), ('table_2', 'world_rank')): 0.25867498}
# {   (('table_1', 'area_served'), ('table_2', 'country')): 0.9680420052450134,
#     (('table_1', 'ceo'), ('table_2', 'CEO')): 0.8737783225421188,
#     (('table_1', 'country'), ('table_2', 'country')): 0.8958543216760945,
#     (('table_1', 'employees'), ('table_2', 'marketCap')): 0.8598262130988349,
#     (('table_1', 'employees'), ('table_2', 'marketValue')): 0.8361350228410322,
#     (('table_1', 'employees'), ('table_2', 'world_rank')): 0.9394691143057584,
#     (('table_1', 'headquarters'), ('table_2', 'country')): 0.864110824523365,
#     (('table_1', 'name'), ('table_2', 'name')): 0.9963237664470591,
#     (('table_1', 'stock'), ('table_2', 'name')): 0.8982115742925795}
# 46 datasets\wiki.json
# 47 datasets\sole24ore.csv
# {   (('table_1', 'name'), ('table_2', 'Unnamed: 1')): 0.24381907,
#     (('table_1', 'share_price'), ('table_2', 'E-commerce')): 0.19595522}
# {   (('table_1', 'employees'), ('table_2', '7.337')): 0.9639885737826316,
#     (('table_1', 'headquarters'), ('table_2', 'Unnamed: 1')): 0.929718649869444,
#     (('table_1', 'name'), ('table_2', 'Winelivery S.r.l.')): 0.9873229982875441}
# {   (('table_1', 'founded'), ('table_2', 'Founded')): 0.84718883,
#     (('table_1', 'headquarters'), ('table_2', 'Headquarters')): 0.8572156,
#     (('table_1', 'industry'), ('table_2', 'Industry')): 0.8496398,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.837735,
#     (('table_1', 'sector'), ('table_2', 'Sector')): 0.84443146}
# 48 datasets\valuetoday.csv
# {   (('table_1', 'ceo'), ('table_2', 'CEO')): 0.81191677,
#     (('table_1', 'country'), ('table_2', 'Country')): 0.8254914,
#     (('table_1', 'employees'), ('table_2', 'Number of Employees')): 0.56752574,
#     (('table_1', 'founded'), ('table_2', 'Founded Year')): 0.577803,
#     (('table_1', 'market_cap'), ('table_2', 'Market Value')): 0.48133063,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.8160376,
#     (('table_1', 'sector'), ('table_2', 'IPO Year')): 0.2781058}
# {   (('table_1', 'area_served'), ('table_2', 'Country')): 0.9543294312894969,
#     (('table_1', 'country'), ('table_2', 'Country')): 0.9948474967044348,
#     (('table_1', 'employees'), ('table_2', 'Number of Employees')): 0.977543491722247,
#     (('table_1', 'founded'), ('table_2', 'Founded Year')): 0.9531971696301018,
#     (('table_1', 'founded'), ('table_2', 'IPO Year')): 0.8668279656403518,
#     (('table_1', 'founders'), ('table_2', 'CEO')): 0.917683300389924,
#     (('table_1', 'headquarters'), ('table_2', 'Country')): 0.9524654052044902,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.9830292564396724,
#     (('table_1', 'stock'), ('table_2', 'Name')): 0.9354027067285773}
# 49 datasets\wissel-activity-ariregister.rik.ee.csv
# {   (('table_1', 'area_served'), ('table_2', 'Area of Activity')): 0.26540965,
#     (('table_1', 'name'), ('table_2', 'NACE Code')): 0.3383154,
#     (('table_1', 'share_price'), ('table_2', 'Source')): 0.29159796}
# {(('table_1', 'employees'), ('table_2', 'ID azienda')): 0.9677771310948965}
# 50 datasets\wissel-aziende-ariregister.rik.ee.csv
# {   (('table_1', 'address'), ('table_2', 'Address')): 0.7784903,
#     (('table_1', 'country'), ('table_2', 'Code')): 0.31884447,
#     (('table_1', 'founded'), ('table_2', 'ID')): 0.27663088,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.7690364,
#     (('table_1', 'revenue'), ('table_2', 'Registration Date')): 0.27065986,
#     (('table_1', 'stock'), ('table_2', 'Status')): 0.32836828,
#     (('table_1', 'website'), ('table_2', 'Deletion Date')): 0.25594124}
# {(('table_1', 'employees'), ('table_2', 'ID')): 0.9456236311187801}
# 51 datasets\wissel-aziende-companiesmarketcap.com.csv
# {   (('table_1', 'country'), ('table_2', 'Company code')): 0.28980163,
#     (('table_1', 'employees'), ('table_2', 'Employees')): 0.8212662,
#     (('table_1', 'founded'), ('table_2', 'ID')): 0.31476283,
#     (('table_1', 'market_cap'), ('table_2', 'Marketcap')): 0.68153137,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.80716836,
#     (('table_1', 'revenue'), ('table_2', 'Revenue')): 0.8166222,
#     (('table_1', 'share_price'), ('table_2', 'Share price')): 0.67392665}
# {   (('table_1', 'employees'), ('table_2', 'ID')): 0.9055292919892227,
#     (('table_1', 'employees'), ('table_2', 'Unnamed: 0')): 0.9258394995130161,
#     (('table_1', 'founded'), ('table_2', 'ID')): 0.9431956009057773,
#     (('table_1', 'founded'), ('table_2', 'Unnamed: 0')): 0.9208809601675008,
#     (('table_1', 'headquarters'), ('table_2', 'Company code')): 0.9754588044236827,
#     (('table_1', 'headquarters'), ('table_2', 'Name')): 0.9682676277331046,
#     (('table_1', 'market_cap'), ('table_2', 'Marketcap')): 0.8468550682249395,
#     (('table_1', 'name'), ('table_2', 'Company code')): 0.9708574843836183,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.9889819150622391,
#     (('table_1', 'revenue'), ('table_2', 'Employees')): 0.9601513748040988,
#     (('table_1', 'share_price'), ('table_2', 'Share price')): 0.9821843111606291,
#     (('table_1', 'stock'), ('table_2', 'Company code')): 0.9329642611529888,
#     (('table_1', 'stock'), ('table_2', 'Name')): 0.9280694929307262}
# 52 datasets\wissel-aziende-gov.uk.csv
# {   (('table_1', 'address'), ('table_2', 'Office Address')): 0.50839466,
#     (('table_1', 'country'), ('table_2', 'Company ID')): 0.24749565,
#     (('table_1', 'founded'), ('table_2', 'ID')): 0.26168597,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.7540915,
#     (('table_1', 'revenue'), ('table_2', 'Registration Date')): 0.25571492}
# {(('table_1', 'employees'), ('table_2', 'ID')): 0.9247287511053677}
# 53 datasets\wissel-aziende-info-clipper.com.csv
# {   (('table_1', 'address'), ('table_2', 'Address Name')): 0.5438457,
#     (('table_1', 'country'), ('table_2', 'Country')): 0.79153407,
#     (('table_1', 'industry'), ('table_2', 'INDEX')): 0.38333443,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.78208023,
#     (('table_1', 'stock'), ('table_2', 'State')): 0.34517553}
# {   (('table_1', 'employees'), ('table_2', 'INDEX')): 0.9385393960202176,
#     (('table_1', 'employees'), ('table_2', 'Unnamed: 0')): 0.8985974853661525,
#     (('table_1', 'founded'), ('table_2', 'INDEX')): 0.8699809543605187,
#     (('table_1', 'founded'), ('table_2', 'Unnamed: 0')): 0.8698907804652154,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.9900211078417316,
#     (('table_1', 'name'), ('table_2', 'Trade Name')): 0.9708992471880806,
#     (('table_1', 'stock'), ('table_2', 'Name')): 0.9330820737228596,
#     (('table_1', 'stock'), ('table_2', 'Trade Name')): 0.9410003693167611}
# 54 datasets\wissel-categorie-companiesmarketcap.com.csv
# {   (('table_1', 'country'), ('table_2', 'Category')): 0.2939977,
#     (('table_1', 'share_price'), ('table_2', 'Hash')): 0.16308711}
# {   (('table_1', 'employees'), ('table_2', 'Company ID')): 0.9671726038951204,
#     (('table_1', 'founded'), ('table_2', 'Company ID')): 0.9156718594583173,
#     (('table_1', 'industry'), ('table_2', 'Category')): 0.9085723702256457,
#     (('table_1', 'sector'), ('table_2', 'Category')): 0.9124385533545148}
# 55 datasets\wissel-partners-ariregister.rik.ee.csv
# {   (('table_1', 'address'), ('table_2', 'ID azienda')): 0.17709608,
#     (('table_1', 'country'), ('table_2', 'Code')): 0.29463252,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.7448245}
# {(('table_1', 'employees'), ('table_2', 'ID azienda')): 0.9483101024942419}
# 56 datasets\wissel-rappresentanti-ariregister.rik.ee.csv
# {   (('table_1', 'address'), ('table_2', 'ID azienda')): 0.18754447,
#     (('table_1', 'country'), ('table_2', 'Code')): 0.3050809,
#     (('table_1', 'name'), ('table_2', 'Name')): 0.75527287,
#     (('table_1', 'revenue'), ('table_2', 'Role')): 0.3050809,
#     (('table_1', 'stock'), ('table_2', 'Start Date')): 0.2641075,
#     (('table_1', 'website'), ('table_2', 'Start Date')): 0.26219055}
# {(('table_1', 'employees'), ('table_2', 'ID azienda')): 0.9214451906205794}
#                                                      name  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 198610  \n                                Olajide Semi...
# 198611  \n                                Kaidi Klein\...
# 198612  \n                                Liridon Resh...
# 198613  \n                                Margus L\xc3...
# 198614  \n                                Hannes Rosin...
#
#                                industry market_cap employees        country  \
# 0               Artificial intelligence        NaN       NaN          China
# 1                                 Other        NaN       NaN  United States
# 2       E-commerce & direct-to-consumer        NaN       NaN          China
# 3                               Fintech        NaN       NaN  United States
# 4          Internet software & services        NaN       NaN      Australia
# ...                                 ...        ...       ...            ...
# 198610                              NaN        NaN       NaN            NaN
# 198611                              NaN        NaN       NaN            NaN
# 198612                              NaN        NaN       NaN            NaN
# 198613                              NaN        NaN       NaN            NaN
# 198614                              NaN        NaN       NaN            NaN
#
#        headquarters address sector  ceo founded founders share_price website  \
# 0               NaN     NaN    NaN  NaN     NaN      NaN         NaN     NaN
# 1               NaN     NaN    NaN  NaN     NaN      NaN         NaN     NaN
# 2               NaN     NaN    NaN  NaN     NaN      NaN         NaN     NaN
# 3               NaN     NaN    NaN  NaN     NaN      NaN         NaN     NaN
# 4               NaN     NaN    NaN  NaN     NaN      NaN         NaN     NaN
# ...             ...     ...    ...  ...     ...      ...         ...     ...
# 198610          NaN     NaN    NaN  NaN     NaN      NaN         NaN     NaN
# 198611          NaN     NaN    NaN  NaN     NaN      NaN         NaN     NaN
# 198612          NaN     NaN    NaN  NaN     NaN      NaN         NaN     NaN
# 198613          NaN     NaN    NaN  NaN     NaN      NaN         NaN     NaN
# 198614          NaN     NaN    NaN  NaN     NaN      NaN         NaN     NaN
#
#        stock area_served revenue
# 0        NaN         NaN     NaN
# 1        NaN         NaN     NaN
# 2        NaN         NaN     NaN
# 3        NaN         NaN     NaN
# 4        NaN         NaN     NaN
# ...      ...         ...     ...
# 198610   NaN         NaN     NaN
# 198611   NaN         NaN     NaN
# 198612   NaN         NaN     NaN
# 198613   NaN         NaN     NaN
# 198614   NaN         NaN     NaN
#
# [198615 rows x 16 columns]
#                                                      name  \
# 0                                 Avis Budget Group, Inc.
# 1                                    Telefônica Brasil SA
# 2                              East Japan Railway Company
# 3                                             Twilio Inc.
# 4                                 Delta Electronics, Inc.
# ...                                                   ...
# 200610  \n                                Olajide Semi...
# 200611  \n                                Kaidi Klein\...
# 200612  \n                                Liridon Resh...
# 200613  \n                                Margus L\xc3...
# 200614  \n                                Hannes Rosin...
#
#                               industry market_cap employees        country  \
# 0            Rental & Leasing Services   $18.12 B    16,000  United States
# 1                     Telecom Services   $20.19 B    34,000         Brazil
# 2                            Railroads   $22.78 B    71,973          Japan
# 3       Internet Content & Information   $26.09 B     7,867  United States
# 4                Electronic Components   $24.05 B                   Taiwan
# ...                                ...        ...       ...            ...
# 200610                             NaN        NaN       NaN            NaN
# 200611                             NaN        NaN       NaN            NaN
# 200612                             NaN        NaN       NaN            NaN
# 200613                             NaN        NaN       NaN            NaN
# 200614                             NaN        NaN       NaN            NaN
#
#                         headquarters address                  sector  \
# 0         Parsippany,NJ,UnitedStates    None             Industrials
# 1                SÃ£oPaulo,SP,Brazil    None  Communication Services
# 2                        Tokyo,Japan    None             Industrials
# 3       SanFrancisco,CA,UnitedStates    None  Communication Services
# 4                      Taipei,Taiwan    None              Technology
# ...                              ...     ...                     ...
# 200610                           NaN     NaN                     NaN
# 200611                           NaN     NaN                     NaN
# 200612                           NaN     NaN                     NaN
# 200613                           NaN     NaN                     NaN
# 200614                           NaN     NaN                     NaN
#
#                                  ceo founded founders share_price website  \
# 0              Mr. Joseph A. Ferraro   2006       NaN         NaN    None
# 1        Mr. Christian  Mauad Gebara    1998      NaN         NaN    None
# 2                 Mr. Yuji  Fukasawa              NaN         NaN    None
# 3                Mr. Jeffrey  Lawson    2008      NaN         NaN    None
# 4                    Mr. Ping  Cheng              NaN         NaN    None
# ...                              ...     ...      ...         ...     ...
# 200610                           NaN     NaN      NaN         NaN     NaN
# 200611                           NaN     NaN      NaN         NaN     NaN
# 200612                           NaN     NaN      NaN         NaN     NaN
# 200613                           NaN     NaN      NaN         NaN     NaN
# 200614                           NaN     NaN      NaN         NaN     NaN
#
#        stock area_served revenue
# 0        CAR         NaN    None
# 1        VIV         NaN    None
# 2       9020         NaN    None
# 3       TWLO         NaN    None
# 4       2308         NaN    None
# ...      ...         ...     ...
# 200610   NaN         NaN     NaN
# 200611   NaN         NaN     NaN
# 200612   NaN         NaN     NaN
# 200613   NaN         NaN     NaN
# 200614   NaN         NaN     NaN
#
# [200615 rows x 16 columns]
#         tab1     attr1                                          tab2  \
# 0    table_1  industry                               cbinsights.json
# 1    table_1   country                               cbinsights.json
# 2    table_1    sector                               cbinsights.json
# 3    table_1   founded                               cbinsights.json
# 4    table_1      name                               cbinsights.json
# ..       ...       ...                                           ...
# 351  table_1   country  wissel-rappresentanti-ariregister.rik.ee.csv
# 352  table_1   revenue  wissel-rappresentanti-ariregister.rik.ee.csv
# 353  table_1     stock  wissel-rappresentanti-ariregister.rik.ee.csv
# 354  table_1   website  wissel-rappresentanti-ariregister.rik.ee.csv
# 355  table_1   address  wissel-rappresentanti-ariregister.rik.ee.csv
#
#                attr2      prob matcher
# 0           industry  0.783709    Coma
# 1            country  0.781258    Coma
# 2    selectinvestors  0.351799    Coma
# 3         datejoined  0.283484    Coma
# 4          valuation  0.225108    Coma
# ..               ...       ...     ...
# 351             Code  0.305081    Coma
# 352             Role  0.305081    Coma
# 353       Start Date  0.264107    Coma
# 354       Start Date  0.262191    Coma
# 355       ID azienda  0.187544    Coma
#
# [356 rows x 6 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 177
#     175 display(df_confronto)
#     176 display(df_logmachers)
# --> 177 print("Tempo Esecuzione: " + total_time)
#
# TypeError: can only concatenate str (not "float") to str

# %%
#formati csv
df1.to_csv('output_alignment/schema_mediato.csv')
df_logmachers.to_csv('output_alignment/log_matchers.csv')
df_confronto.to_csv('output_alignment/schema_mediato_incrementale_confronto.csv')
#formati json
df1.to_json('output_alignment/schema_mediato.json')
df_logmachers.to_json('output_alignment/log_matchers.json')
df_confronto.to_json('output_alignment/schema_mediato_incrementale_confronto.json')

# %% [markdown]
# # Il codice sottostante è utilizzato per generare il dataframe di un singolo dataset

# %%
df1 = pd.DataFrame(columns = ['name' , 'industry', 'market_cap', 'employees', 'country', 'headquarters', 'address', 'sector', 'ceo', 'founded', 'founders', 'share_price', 'website', 'stock', 'area_served', 'revenue'])
df_confronto = pd.read_json('schema_mediato_auto.json')
df_logmachers = pd.DataFrame(columns = ['tab1' , 'attr1', 'tab2', 'attr2', 'prob', 'matcher'])



df2 = pd.read_csv('datasets/DDD-cbinsight.com.csv', encoding='ISO-8859-1')
# df2 = pd.read_json('datasets/output_wiki.json')
# trasforma le celle del dataframe che hanno liste in stringhe
df2 = df2.applymap(list2string)
df1, df_logmachers, df_confronto = creation_schema_alignment(df1, df2, df_confronto, df_logmachers, 'companiesMarketCap_dataset.jsonl')

display(df1)
display(df_logmachers)
display(df_confronto)
# Out:
# {   (('table_1', 'country'), ('table_2', 'country')): 0.81663823,
#     (('table_1', 'founded'), ('table_2', 'founded')): 0.81663823,
#     (('table_1', 'industry'), ('table_2', 'industry')): 0.8190892,
#     (('table_1', 'name'), ('table_2', 'name')): 0.8071844,
#     (('table_1', 'stock'), ('table_2', 'stage')): 0.37027967}
# {   (('table_1', 'country'), ('table_2', 'city')): 0.9282149206585528,
#     (('table_1', 'country'), ('table_2', 'country')): 0.9527752093616784,
#     (('table_1', 'headquarters'), ('table_2', 'city')): 0.9105745288665776,
#     (('table_1', 'headquarters'), ('table_2', 'country')): 0.9224909701879977}
#             name                             industry market_cap employees  \
# 0       Lacework                        Cybersecurity        NaN       NaN
# 1        Tipalti                              Fintech        NaN       NaN
# 2         Tempus                               Health        NaN       NaN
# 3        Anduril              Artificial intelligence        NaN       NaN
# 4           Bolt                Auto & transportation        NaN       NaN
# ...          ...                                  ...        ...       ...
# 1180      SpaceX                                Other        NaN       NaN
# 1181    Fanatics      E-commerce & direct-to-consumer        NaN       NaN
# 1182   Instacart  Supply chain, logistics, & delivery        NaN       NaN
# 1183  Databricks          Data management & analytics        NaN       NaN
# 1184      Stripe                              Fintech        NaN       NaN
#
#             country headquarters address sector  ceo founded founders  \
# 0     United States          NaN     NaN    NaN  NaN    2015      NaN
# 1     United States          NaN     NaN    NaN  NaN    2010      NaN
# 2     United States          NaN     NaN    NaN  NaN    2015      NaN
# 3     United States          NaN     NaN    NaN  NaN    2017      NaN
# 4           Estonia          NaN     NaN    NaN  NaN    2013      NaN
# ...             ...          ...     ...    ...  ...     ...      ...
# 1180  United States          NaN     NaN    NaN  NaN    2002      NaN
# 1181  United States          NaN     NaN    NaN  NaN    1995      NaN
# 1182  United States          NaN     NaN    NaN  NaN    2012      NaN
# 1183  United States          NaN     NaN    NaN  NaN    2013      NaN
# 1184  United States          NaN     NaN    NaN  NaN    2010      NaN
#
#      share_price website stock area_served revenue
# 0            NaN     NaN   NaN         NaN     NaN
# 1            NaN     NaN   NaN         NaN     NaN
# 2            NaN     NaN   NaN         NaN     NaN
# 3            NaN     NaN   NaN         NaN     NaN
# 4            NaN     NaN   NaN         NaN     NaN
# ...          ...     ...   ...         ...     ...
# 1180         NaN     NaN   NaN         NaN     NaN
# 1181         NaN     NaN   NaN         NaN     NaN
# 1182         NaN     NaN   NaN         NaN     NaN
# 1183         NaN     NaN   NaN         NaN     NaN
# 1184         NaN     NaN   NaN         NaN     NaN
#
# [1185 rows x 16 columns]
#       tab1     attr1                              tab2     attr2      prob  \
# 0  table_1  industry  companiesMarketCap_dataset.jsonl  industry  0.819089
# 1  table_1   country  companiesMarketCap_dataset.jsonl   country  0.816638
# 2  table_1   founded  companiesMarketCap_dataset.jsonl   founded  0.816638
# 3  table_1      name  companiesMarketCap_dataset.jsonl      name  0.807184
# 4  table_1     stock  companiesMarketCap_dataset.jsonl     stage  0.370280
#
#   matcher
# 0    Coma
# 1    Coma
# 2    Coma
# 3    Coma
# 4    Coma
#                             name                             industry  \
# 0        Avis Budget Group, Inc.            Rental & Leasing Services
# 1           Telefônica Brasil SA                     Telecom Services
# 2     East Japan Railway Company                            Railroads
# 3                    Twilio Inc.       Internet Content & Information
# 4        Delta Electronics, Inc.                Electronic Components
# ...                          ...                                  ...
# 3180                      SpaceX                                Other
# 3181                    Fanatics      E-commerce & direct-to-consumer
# 3182                   Instacart  Supply chain, logistics, & delivery
# 3183                  Databricks          Data management & analytics
# 3184                      Stripe                              Fintech
#
#      market_cap employees        country                  headquarters  \
# 0      $18.12 B    16,000  United States    Parsippany,NJ,UnitedStates
# 1      $20.19 B    34,000         Brazil           SÃ£oPaulo,SP,Brazil
# 2      $22.78 B    71,973          Japan                   Tokyo,Japan
# 3      $26.09 B     7,867  United States  SanFrancisco,CA,UnitedStates
# 4      $24.05 B                   Taiwan                 Taipei,Taiwan
# ...         ...       ...            ...                           ...
# 3180        NaN       NaN  United States                           NaN
# 3181        NaN       NaN  United States                           NaN
# 3182        NaN       NaN  United States                           NaN
# 3183        NaN       NaN  United States                           NaN
# 3184        NaN       NaN  United States                           NaN
#
#      address                  sector                           ceo founded  \
# 0       None             Industrials         Mr. Joseph A. Ferraro   2006
# 1       None  Communication Services   Mr. Christian  Mauad Gebara    1998
# 2       None             Industrials            Mr. Yuji  Fukasawa
# 3       None  Communication Services           Mr. Jeffrey  Lawson    2008
# 4       None              Technology               Mr. Ping  Cheng
# ...      ...                     ...                           ...     ...
# 3180     NaN                     NaN                           NaN    2002
# 3181     NaN                     NaN                           NaN    1995
# 3182     NaN                     NaN                           NaN    2012
# 3183     NaN                     NaN                           NaN    2013
# 3184     NaN                     NaN                           NaN    2010
#
#       founders  share_price website stock  area_served revenue
# 0          NaN          NaN    None   CAR          NaN    None
# 1          NaN          NaN    None   VIV          NaN    None
# 2          NaN          NaN    None  9020          NaN    None
# 3          NaN          NaN    None  TWLO          NaN    None
# 4          NaN          NaN    None  2308          NaN    None
# ...        ...          ...     ...   ...          ...     ...
# 3180       NaN          NaN     NaN   NaN          NaN     NaN
# 3181       NaN          NaN     NaN   NaN          NaN     NaN
# 3182       NaN          NaN     NaN   NaN          NaN     NaN
# 3183       NaN          NaN     NaN   NaN          NaN     NaN
# 3184       NaN          NaN     NaN   NaN          NaN     NaN
#
# [3185 rows x 16 columns]

# %%
original_columns=["name", "industry", "market_cap", "employees", "country", "headquarters", "address", "sector", "ceo", "founded", "founders", "share_price", "website", "stock", "area_served", "revenue"]
schema_mediato = pd.DataFrame(columns=original_columns)

df_gd = pd.read_json('datasets/output_globaldata.json')
df_gd.rename(columns={"number_of_employees":"employees"}, inplace=True)

df_disfold = pd.read_json('datasets/output_disfold.json')

df_vt = pd.read_json('datasets/gren-value.today.json')
df_vt.rename(columns={"annual_revenue_USD":"revenue", "annual_net_income_USD":"earnings", "employees_number":"employees", "headquarters_country": "headquarters", "market_capitalization_2022": "market_cap", "CEO":"ceo"}, inplace=True)

df_vt2 = pd.read_json('datasets/valueToday2.json')
df_vt2.rename(columns={"marketCap":"market_cap", "country": "country", "CEO":"ceo"}, inplace=True)

schema_mediato = schema_mediato.append(df_disfold[:500], ignore_index=True)
schema_mediato = schema_mediato.append(df_vt[:500], ignore_index=True)
schema_mediato = schema_mediato.append(df_vt2[:500], ignore_index=True)
schema_mediato = schema_mediato.append(df_gd[:500], ignore_index=True)

schema_mediato[original_columns].to_json('schema_mediato_auto.json', orient='records')
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_14896\198771844.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schema_mediato = schema_mediato.append(df_disfold[:500], ignore_index=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_14896\198771844.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schema_mediato = schema_mediato.append(df_vt[:500], ignore_index=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_14896\198771844.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schema_mediato = schema_mediato.append(df_vt2[:500], ignore_index=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_14896\198771844.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schema_mediato = schema_mediato.append(df_gd[:500], ignore_index=True)
